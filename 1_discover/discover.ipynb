# %%
import pandas as pd

# %% [markdown]
# ## Steam popularity

# %%
steam_charts = pd.read_csv("../data/SteamCharts.csv", encoding='unicode_escape')

# %%
steam_charts.shape
# Out:
# (83789, 7)

# %%
steam_charts.sample(5)
# Out:
#                   gamename  year     month      avg    gain  peak  \
# 8381        Fishing Planet  2015   August   2058.52     NaN  6651
# 60734  Supreme Commander 2  2014  October    381.83  -58.76   833
# 61505          Tower Unite  2020     July    331.80   69.96   585
# 79379    The Final Station  2016     June      0.81   -2.08    10
# 29580            Half-Life  2018     June    499.52  169.86  1420
#
#       avg_peak_perc
# 8381       30.9505%
# 60734      45.8379%
# 61505      56.7179%
# 79379          8.1%
# 29580      35.1775%

# %%
df_charts = steam_charts.copy(deep=True)

# %%
df_charts['month'].unique()
# Out:
# array(['February ', 'January ', 'December ', 'November ', 'October ',
#        'September ', 'August ', 'July ', 'June ', 'May ', 'April ',
#        'March '], dtype=object)

# %%
df_charts['month'] = df_charts['month'].str.strip()

# %%
# create new date column
df_charts['month_number'] = pd.to_datetime(df_charts['month'], format='%B').dt.month

# %%
df_charts.sort_values(by=['year', 'month'], inplace=True)

# %%
df_charts
# Out:
#                                gamename  year    month       avg      gain  \
# 102    Counter-Strike: Global Offensive  2012   August  15475.39  14542.81
# 206                              Dota 2  2012   August  55768.61   3047.56
# 449                     Team Fortress 2  2012   August  61561.37  15994.47
# 989                            PAYDAY 2  2012   August      0.00       NaN
# 1405                        Garry's Mod  2012   August   6867.33  -1098.61
# ...                                 ...   ...      ...       ...       ...
# 83428                         Teeworlds  2021  January     37.25     -2.37
# 83495                           Far Cry  2021  January     86.17     11.31
# 83599                       Axiom Verge  2021  January     27.00      5.74
# 83670                       Plug & Play  2021  January      1.49      0.31
# 83742       Steel Division: Normandy 44  2021  January    117.34     13.49
#
#          peak avg_peak_perc  month_number
# 102     52261      29.6117%             8
# 206    108689      51.3103%             8
# 449    117917      52.2074%             8
# 989         0          NaN%             8
# 1405    10711      64.1147%             8
# ...       ...           ...           ...
# 83428     101      36.8812%             1
# 83495     224      38.4688%             1
# 83599      67      40.2985%             1
# 83670       6      24.8333%             1
# 83742     308      38.0974%             1
#
# [83789 rows x 8 columns]

# %%
print(f"Start year and month: {df_charts.iloc[0]['year']} {df_charts.iloc[0]['month']}")
print(f"End year and month: {df_charts.iloc[-1]['year']} {df_charts.iloc[-1]['month']}")
# Out:
# Start year and month: 2012 August
# End year and month: 2021 January

# %% [markdown]
# ## Steam game releases

# %%
steam_releases = pd.read_csv("../data/SteamReleases.csv")

# %%
steam_releases.sample(5)
# Out:
#          AppID                                          Name  Release date  \
# 12790   740390                         Terrorist Elimination   Nov 7, 2017
# 20340   434890                             Eight Mini Racers  Jan 12, 2016
# 28122  1177650  Paper Shakespeare: To Date or Not To Date? 2  Sep 23, 2020
# 53521  1094460                    Tiger Tank 59 Ⅰ Battleship  Jun 10, 2019
# 44744  1939940                  Roll Player - The Board Game  May 20, 2022
#
#       Estimated owners  Peak CCU  Required age  Price  DLC count  \
# 12790        0 - 20000         0             0   5.99          0
# 20340   50000 - 100000         0             0   0.49          0
# 28122        0 - 20000         0             0   9.99          2
# 53521        0 - 20000         0             0   0.00        100
# 44744        0 - 20000         1             0  14.99          0
#
#                                           About the game Supported languages  \
# 12790  GamePlay: Purchase guns and ammo in the store,...         ['English']
# 20340  1 - 8 player local multiplayer 2D top-down rac...         ['English']
# 28122  King Alexander XI is dead, and without heir. Y...         ['English']
# 53521  'Tiger Tank 59' is a top-down shooting game In...         ['English']
# 44744  Roll Player is a digital adaptation of the pop...         ['English']
#
#        ... Average playtime two weeks Median playtime forever  \
# 12790  ...                          0                       0
# 20340  ...                          0                     212
# 28122  ...                          0                       0
# 53521  ...                          0                       0
# 44744  ...                          0                       0
#
#       Median playtime two weeks                      Developers  \
# 12790                         0                    ReverseGames
# 20340                         0                    David Mulder
# 28122                         0  Stegalosaurus Game Development
# 53521                         0                     TigerQiuQiu
# 44744                         0                          Mipmap
#
#                            Publishers  \
# 12790                    ReverseGames
# 20340                     SA Industry
# 28122  Stegalosaurus Game Development
# 53521                     TigerQiuQiu
# 44744                          Mipmap
#
#                                               Categories  \
# 12790                                      Single-player
# 20340  Single-player,Multi-player,Shared/Split Screen...
# 28122                   Single-player,Steam Achievements
# 53521  Single-player,Steam Achievements,Full controll...
# 44744  Single-player,Multi-player,PvP,Shared/Split Sc...
#
#                              Genres  \
# 12790         Violent,Action,Casual
# 20340                 Casual,Racing
# 28122      Adventure,Indie,Strategy
# 53521           Action,Casual,Indie
# 44744  Casual,Strategy,Early Access
#
#                                                     Tags  \
# 12790                              Action,Violent,Casual
# 20340                                      Racing,Casual
# 28122                                                NaN
# 53521                                Action,Indie,Casual
# 44744  Early Access,Strategy,Board Game,Character Cus...
#
#                                              Screenshots  \
# 12790  https://cdn.akamai.steamstatic.com/steam/apps/...
# 20340  https://cdn.akamai.steamstatic.com/steam/apps/...
# 28122  https://cdn.akamai.steamstatic.com/steam/apps/...
# 53521  https://cdn.akamai.steamstatic.com/steam/apps/...
# 44744  https://cdn.akamai.steamstatic.com/steam/apps/...
#
#                                                   Movies
# 12790  http://cdn.akamai.steamstatic.com/steam/apps/2...
# 20340  http://cdn.akamai.steamstatic.com/steam/apps/2...
# 28122  http://cdn.akamai.steamstatic.com/steam/apps/2...
# 53521  http://cdn.akamai.steamstatic.com/steam/apps/2...
# 44744  http://cdn.akamai.steamstatic.com/steam/apps/2...
#
# [5 rows x 39 columns]

# %%
for col in steam_releases.columns:
    print(f"{col}")
# Out:
# AppID
# Name
# Release date
# Estimated owners
# Peak CCU
# Required age
# Price
# DLC count
# About the game
# Supported languages
# Full audio languages
# Reviews
# Header image
# Website
# Support url
# Support email
# Windows
# Mac
# Linux
# Metacritic score
# Metacritic url
# User score
# Positive
# Negative
# Score rank
# Achievements
# Recommendations
# Notes
# Average playtime forever
# Average playtime two weeks
# Median playtime forever
# Median playtime two weeks
# Developers
# Publishers
# Categories
# Genres
# Tags
# Screenshots
# Movies

# %%
steam_releases.shape
# Out:
# (71716, 39)

# %%
df_releases = steam_releases.copy(deep=True)

# %% [markdown]
# Transform Release Date into uniform date because the column has two different formats: '%b %Y' (May 2020) and '%b %d, %Y' (May 21, 2020). New format: '%Y-%m-%d'

# %%
# convert different date formats
df_releases['temp_date'] = pd.to_datetime(df_releases['Release date'], format='%b %Y', errors='coerce')
df_releases['temp_date'] = df_releases['temp_date'].dt.strftime('%Y-%m-%d')

df_releases['temp_date_2'] = pd.to_datetime(df_releases['Release date'], format='%b %d, %Y', errors='coerce')
df_releases['temp_date_2'] = df_releases['temp_date_2'].dt.strftime('%Y-%m-%d')

# %%
# change dtype in df
df_releases['Release date'] = df_releases['temp_date'].combine_first(df_releases['temp_date_2'])
df_releases['Release date'] = pd.to_datetime(df_releases['Release date'])

# %%
# create and sort index
df_releases.sort_values(by='Release date', inplace=True)

# %%
print(f"Start date: {df_releases['Release date'].min()}\nEnd date: {df_releases['Release date'].max()}")
# Out:
# Start date: 1997-06-30 00:00:00
# End date: 2025-04-14 00:00:00

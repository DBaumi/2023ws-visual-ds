# %%
import pandas as pd

# %% [markdown]
# ## Steam popularity

# %%
steam_charts = pd.read_csv("data/SteamCharts.csv", encoding='unicode_escape')

# %%
steam_charts.shape
# Out:
# (83789, 7)

# %%
steam_charts.sample(5)
# Out:
#                                        gamename  year     month     avg  \
# 72511                           Among the Sleep  2020  October    14.28
# 80398                     Anomaly Warzone Earth  2013      May    16.16
# 40291                                 Sanctum 2  2013      May   810.19
# 73815                    Woodle Tree Adventures  2015      May     3.30
# 63671  The Incredible Adventures of Van Helsing  2015    March    99.33
#
#         gain  peak avg_peak_perc
# 72511   1.94    62      23.0323%
# 80398   7.97    50        32.32%
# 40291    NaN  2448       33.096%
# 73815  -2.73    10           33%
# 63671 -15.21   228      43.5658%

# %%
df_charts = steam_charts.copy(deep=True)

# %%
df_charts['month'].unique()
# Out:
# array(['February ', 'January ', 'December ', 'November ', 'October ',
#        'September ', 'August ', 'July ', 'June ', 'May ', 'April ',
#        'March '], dtype=object)

# %%
df_charts['month'] = df_charts['month'].str.strip()

# %%
# create new date column
df_charts['month_number'] = pd.to_datetime(df_charts['month'], format='%B').dt.month

# %%
df_charts.sort_values(by=['year', 'month'], inplace=True)

# %%
df_charts
# Out:
#                                gamename  year    month       avg      gain  \
# 102    Counter-Strike: Global Offensive  2012   August  15475.39  14542.81
# 206                              Dota 2  2012   August  55768.61   3047.56
# 449                     Team Fortress 2  2012   August  61561.37  15994.47
# 989                            PAYDAY 2  2012   August      0.00       NaN
# 1405                        Garry's Mod  2012   August   6867.33  -1098.61
# ...                                 ...   ...      ...       ...       ...
# 83428                         Teeworlds  2021  January     37.25     -2.37
# 83495                           Far Cry  2021  January     86.17     11.31
# 83599                       Axiom Verge  2021  January     27.00      5.74
# 83670                       Plug & Play  2021  January      1.49      0.31
# 83742       Steel Division: Normandy 44  2021  January    117.34     13.49
#
#          peak avg_peak_perc  month_number
# 102     52261      29.6117%             8
# 206    108689      51.3103%             8
# 449    117917      52.2074%             8
# 989         0          NaN%             8
# 1405    10711      64.1147%             8
# ...       ...           ...           ...
# 83428     101      36.8812%             1
# 83495     224      38.4688%             1
# 83599      67      40.2985%             1
# 83670       6      24.8333%             1
# 83742     308      38.0974%             1
#
# [83789 rows x 8 columns]

# %%
print(f"Start year and month: {df_charts.iloc[0]['year']} {df_charts.iloc[0]['month']}")
print(f"End year and month: {df_charts.iloc[-1]['year']} {df_charts.iloc[-1]['month']}")
# Out:
# Start year and month: 2012 August
# End year and month: 2021 January

# %% [markdown]
# ## Steam game releases

# %%
steam_releases = pd.read_csv("data/games.csv")

# %%
steam_releases.sample(5)
# Out:
#          AppID                                  Name  Release date  \
# 56268   231200       Kentucky Route Zero: PC Edition  Feb 22, 2013
# 42891  1995870           Pixel Survivors : Roguelike  Jun 30, 2022
# 37841  1063020                       Elemental War 2   May 6, 2022
# 29427   407530          ARK: Survival Of The Fittest  Aug 29, 2017
# 48680   284750  Enigmatis: The Ghosts of Maple Creek  Oct 16, 2014
#
#         Estimated owners  Peak CCU  Required age  Price  DLC count  \
# 56268    200000 - 500000        11             0  24.99          0
# 42891          0 - 20000        29             0   1.99          0
# 37841          0 - 20000         1             0  19.99          1
# 29427  1000000 - 2000000        86             0   0.00          0
# 48680     50000 - 100000         6             0   9.99          0
#
#                                           About the game  \
# 56268  At twilight in Kentucky, as bird songs give wa...
# 42891  'Pixel Survivors: Rougelike' is a survival gam...
# 37841  Elemental War 2 takes you into a threatened wo...
# 29427  Welcome to ARK: Survival of the Fittest , the ...
# 48680  Imagine waking up after a powerful storm as th...
#
#                                      Supported languages  ...  \
# 56268  ['English', 'French', 'Italian', 'German', 'Sp...  ...
# 42891  ['English', 'Simplified Chinese', 'Vietnamese'...  ...
# 37841  ['English', 'German', 'Italian', 'Romanian', '...  ...
# 29427  ['English', 'Simplified Chinese', 'Traditional...  ...
# 48680  ['English', 'French', 'Italian', 'German', 'Sp...  ...
#
#       Average playtime two weeks Median playtime forever  \
# 56268                          0                     166
# 42891                          0                       0
# 37841                          0                       0
# 29427                        588                      17
# 48680                          0                     259
#
#       Median playtime two weeks  \
# 56268                         0
# 42891                         0
# 37841                         0
# 29427                       588
# 48680                         0
#
#                                               Developers          Publishers  \
# 56268                                 Cardboard Computer  Cardboard Computer
# 42891                                             Amrita              Amrita
# 37841                                  Clockwork Origins   Clockwork Origins
# 29427  Studio Wildcard,Instinct Games,Efecto Studios,...     Studio Wildcard
# 48680                                      Artifex Mundi       Artifex Mundi
#
#                                               Categories  \
# 56268  Single-player,Steam Achievements,Full controll...
# 42891                   Single-player,Steam Achievements
# 37841  Single-player,Multi-player,Co-op,Online Co-op,...
# 29427  Multi-player,Co-op,Steam Workshop,Partial Cont...
# 48680  Single-player,Steam Achievements,Steam Trading...
#
#                                                   Genres  \
# 56268                                    Adventure,Indie
# 42891               Action,Casual,Indie,RPG,Early Access
# 37841                                     Indie,Strategy
# 29427  Action,Adventure,Indie,Massively Multiplayer,R...
# 48680                                   Adventure,Casual
#
#                                                     Tags  \
# 56268  Adventure,Atmospheric,Indie,Point & Click,Surr...
# 42891  RPG,Action,Rogue-like,Casual,Pixel Graphics,Si...
# 37841  Indie,Strategy,Singleplayer,Replay Value,RTS,T...
# 29427  Free to Play,Survival,Dinosaurs,Multiplayer,Op...
# 48680  Hidden Object,Adventure,Casual,Point & Click,F...
#
#                                              Screenshots  \
# 56268  https://cdn.akamai.steamstatic.com/steam/apps/...
# 42891  https://cdn.akamai.steamstatic.com/steam/apps/...
# 37841  https://cdn.akamai.steamstatic.com/steam/apps/...
# 29427  https://cdn.akamai.steamstatic.com/steam/apps/...
# 48680  https://cdn.akamai.steamstatic.com/steam/apps/...
#
#                                                   Movies
# 56268  http://cdn.akamai.steamstatic.com/steam/apps/2...
# 42891  http://cdn.akamai.steamstatic.com/steam/apps/2...
# 37841  http://cdn.akamai.steamstatic.com/steam/apps/2...
# 29427  http://cdn.akamai.steamstatic.com/steam/apps/2...
# 48680  http://cdn.akamai.steamstatic.com/steam/apps/2...
#
# [5 rows x 39 columns]

# %%
for col in steam_releases.columns:
    print(f"{col}")
# Out:
# AppID
# Name
# Release date
# Estimated owners
# Peak CCU
# Required age
# Price
# DLC count
# About the game
# Supported languages
# Full audio languages
# Reviews
# Header image
# Website
# Support url
# Support email
# Windows
# Mac
# Linux
# Metacritic score
# Metacritic url
# User score
# Positive
# Negative
# Score rank
# Achievements
# Recommendations
# Notes
# Average playtime forever
# Average playtime two weeks
# Median playtime forever
# Median playtime two weeks
# Developers
# Publishers
# Categories
# Genres
# Tags
# Screenshots
# Movies

# %%
steam_releases.shape
# Out:
# (71716, 39)

# %%
df_releases = steam_releases.copy(deep=True)

# %% [markdown]
# Transform Release Date into uniform date because the column has two different formats: '%b %Y' (May 2020) and '%b %d, %Y' (May 21, 2020). New format: '%Y-%m-%d'

# %%
# convert different date formats
df_releases['temp_date'] = pd.to_datetime(df_releases['Release date'], format='%b %Y', errors='coerce')
df_releases['temp_date'] = df_releases['temp_date'].dt.strftime('%Y-%m-%d')

df_releases['temp_date_2'] = pd.to_datetime(df_releases['Release date'], format='%b %d, %Y', errors='coerce')
df_releases['temp_date_2'] = df_releases['temp_date_2'].dt.strftime('%Y-%m-%d')

# %%
# change dtype in df
df_releases['Release date'] = df_releases['temp_date'].combine_first(df_releases['temp_date_2'])
df_releases['Release date'] = pd.to_datetime(df_releases['Release Date'])

# %%
# create and sort index
df_releases.sort_values(by='Release date', inplace=True)

# %%
print(f"Start date: {df_releases['Release date'].min()}\nEnd date: {df_releases['Release date'].max()}")
# Out:
# Start date: 1997-06-30 00:00:00
# End date: 2025-04-14 00:00:00
